# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv(r'/content/drive/MyDrive/MBA/GroceryStoreDataSet.csv',names=['products'],header=None)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                           products
# 0               MILK,BREAD,BISCUIT
# 1    BREAD,MILK,BISCUIT,CORNFLAKES
# 2              BREAD,TEA,BOURNVITA
# 3             JAM,MAGGI,BREAD,MILK
# 4                MAGGI,TEA,BISCUIT
# 5              BREAD,TEA,BOURNVITA
# 6             MAGGI,TEA,CORNFLAKES
# 7          MAGGI,BREAD,TEA,BISCUIT
# 8              JAM,MAGGI,BREAD,TEA
# 9                       BREAD,MILK
# 10  COFFEE,COKE,BISCUIT,CORNFLAKES
# 11  COFFEE,COKE,BISCUIT,CORNFLAKES
# 12          COFFEE,SUGER,BOURNVITA
# 13               BREAD,COFFEE,COKE
# 14             BREAD,SUGER,BISCUIT
# 15         COFFEE,SUGER,CORNFLAKES
# 16           BREAD,SUGER,BOURNVITA
# 17              BREAD,COFFEE,SUGER
# 18              BREAD,COFFEE,SUGER
# 19      TEA,MILK,COFFEE,CORNFLAKES

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (20, 1)

# %%
df.values
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([['MILK,BREAD,BISCUIT'],
#        ['BREAD,MILK,BISCUIT,CORNFLAKES'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['JAM,MAGGI,BREAD,MILK'],
#        ['MAGGI,TEA,BISCUIT'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['MAGGI,TEA,CORNFLAKES'],
#        ['MAGGI,BREAD,TEA,BISCUIT'],
#        ['JAM,MAGGI,BREAD,TEA'],
#        ['BREAD,MILK'],
#        ['COFFEE,COKE,BISCUIT,CORNFLAKES'],
#        ['COFFEE,COKE,BISCUIT,CORNFLAKES'],
#        ['COFFEE,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,COKE'],
#        ['BREAD,SUGER,BISCUIT'],
#        ['COFFEE,SUGER,CORNFLAKES'],
#        ['BREAD,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,SUGER'],
#        ['BREAD,COFFEE,SUGER'],
#        ['TEA,MILK,COFFEE,CORNFLAKES']], dtype=object)

# %%
data = list(df["products"].apply(lambda x:x.split(',')))
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COKE', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COKE'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
x = False
y = 10
print(x*y)
# Out:
# 0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from mlxtend.preprocessing import TransactionEncoder
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     BISCUIT  BOURNVITA  BREAD  COFFEE   COKE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0      True      False   True   False  False       False  False  False   True
# 1      True      False   True   False  False        True  False  False   True
# 2     False       True   True   False  False       False  False  False  False
# 3     False      False   True   False  False       False   True   True   True
# 4      True      False  False   False  False       False  False   True  False
# 5     False       True   True   False  False       False  False  False  False
# 6     False      False  False   False  False        True  False   True  False
# 7      True      False   True   False  False       False  False   True  False
# 8     False      False   True   False  False       False   True   True  False
# 9     False      False   True   False  False       False  False  False   True
# 10     True      False  False    True   True        True  False  False  False
# 11     True      False  False    True   True        True  False  False  False
# 12    False       True  False    True  False       False  False  False  False
# 13    False      False   True    True   True       False  False  False  False
# 14     True      False   True   False  False       False  False  False  False
# 15    False      False  False    True  False        True  False  False  False
# 16    False       True   True   False  False       False  False  False  False
# 17    False      False   True    True  False       False  False  False  False
# 18    False      False   True    True  False       False  False  False  False
# 19    False      False  False    True  False        True  False  False   True
#
#     SUGER    TEA
# 0   False  False
# 1   False  False
# 2   False   True
# 3   False  False
# 4   False   True
# 5   False   True
# 6   False   True
# 7   False   True
# 8   False   True
# 9   False  False
# 10  False  False
# 11  False  False
# 12   True  False
# 13  False  False
# 14   True  False
# 15   True  False
# 16   True  False
# 17   True  False
# 18   True  False
# 19  False   True

# %%
df.sum()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# BISCUIT        7
# BOURNVITA      4
# BREAD         13
# COFFEE         8
# COKE           3
# CORNFLAKES     6
# JAM            2
# MAGGI          5
# MILK           5
# SUGER          6
# TEA            7
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.sum().to_frame('Frequency').sort_values('Frequency',ascending=False).plot(kind='bar',
                                                                                  figsize=(12,8),
                                                                                  title="Frequent Items")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.shape[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 20

# %%
# Product Frequency / Total Sales
first = pd.DataFrame(df.sum() / df.shape[0],columns = ["Support"]).sort_values("Support", ascending = False)
first
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#             Support
# BREAD          0.65
# COFFEE         0.40
# BISCUIT        0.35
# TEA            0.35
# CORNFLAKES     0.30
# SUGER          0.30
# MAGGI          0.25
# MILK           0.25
# BOURNVITA      0.20
# COKE           0.15
# JAM            0.10

# %%
# Elimination by Support Value
first[first.Support >= 0.40]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Support
# BREAD      0.65
# COFFEE     0.40

# %%
import itertools
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
second = list(itertools.combinations(first.index, 2))
second = [list(i) for i in second]
# Sample of combinations
second
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['BREAD', 'COFFEE'],
#  ['BREAD', 'BISCUIT'],
#  ['BREAD', 'TEA'],
#  ['BREAD', 'CORNFLAKES'],
#  ['BREAD', 'SUGER'],
#  ['BREAD', 'MAGGI'],
#  ['BREAD', 'MILK'],
#  ['BREAD', 'BOURNVITA'],
#  ['BREAD', 'COKE'],
#  ['BREAD', 'JAM'],
#  ['COFFEE', 'BISCUIT'],
#  ['COFFEE', 'TEA'],
#  ['COFFEE', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER'],
#  ['COFFEE', 'MAGGI'],
#  ['COFFEE', 'MILK'],
#  ['COFFEE', 'BOURNVITA'],
#  ['COFFEE', 'COKE'],
#  ['COFFEE', 'JAM'],
#  ['BISCUIT', 'TEA'],
#  ['BISCUIT', 'CORNFLAKES'],
#  ['BISCUIT', 'SUGER'],
#  ['BISCUIT', 'MAGGI'],
#  ['BISCUIT', 'MILK'],
#  ['BISCUIT', 'BOURNVITA'],
#  ['BISCUIT', 'COKE'],
#  ['BISCUIT', 'JAM'],
#  ['TEA', 'CORNFLAKES'],
#  ['TEA', 'SUGER'],
#  ['TEA', 'MAGGI'],
#  ['TEA', 'MILK'],
#  ['TEA', 'BOURNVITA'],
#  ['TEA', 'COKE'],
#  ['TEA', 'JAM'],
#  ['CORNFLAKES', 'SUGER'],
#  ['CORNFLAKES', 'MAGGI'],
#  ['CORNFLAKES', 'MILK'],
#  ['CORNFLAKES', 'BOURNVITA'],
#  ['CORNFLAKES', 'COKE'],
#  ['CORNFLAKES', 'JAM'],
#  ['SUGER', 'MAGGI'],
#  ['SUGER', 'MILK'],
#  ['SUGER', 'BOURNVITA'],
#  ['SUGER', 'COKE'],
#  ['SUGER', 'JAM'],
#  ['MAGGI', 'MILK'],
#  ['MAGGI', 'BOURNVITA'],
#  ['MAGGI', 'COKE'],
#  ['MAGGI', 'JAM'],
#  ['MILK', 'BOURNVITA'],
#  ['MILK', 'COKE'],
#  ['MILK', 'JAM'],
#  ['BOURNVITA', 'COKE'],
#  ['BOURNVITA', 'JAM'],
#  ['COKE', 'JAM']]

# %%
from mlxtend.frequent_patterns import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pd.set_option("display.max_rows",None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df1 = apriori(df,min_support=0.01,use_colnames=True)
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                             itemsets
# 0      0.35                            (BISCUIT)
# 1      0.20                          (BOURNVITA)
# 2      0.65                              (BREAD)
# 3      0.40                             (COFFEE)
# 4      0.15                               (COKE)
# 5      0.30                         (CORNFLAKES)
# 6      0.10                                (JAM)
# 7      0.25                              (MAGGI)
# 8      0.25                               (MILK)
# 9      0.30                              (SUGER)
# 10     0.35                                (TEA)
# 11     0.20                     (BISCUIT, BREAD)
# 12     0.10                    (BISCUIT, COFFEE)
# 13     0.10                      (BISCUIT, COKE)
# 14     0.15                (BISCUIT, CORNFLAKES)
# 15     0.10                     (BISCUIT, MAGGI)
# 16     0.10                      (BISCUIT, MILK)
# 17     0.05                     (SUGER, BISCUIT)
# 18     0.10                       (BISCUIT, TEA)
# 19     0.15                   (BOURNVITA, BREAD)
# 20     0.05                  (BOURNVITA, COFFEE)
# 21     0.10                   (SUGER, BOURNVITA)
# 22     0.10                     (BOURNVITA, TEA)
# 23     0.15                      (COFFEE, BREAD)
# 24     0.05                        (COKE, BREAD)
# 25     0.05                  (CORNFLAKES, BREAD)
# 26     0.10                         (JAM, BREAD)
# 27     0.15                       (MAGGI, BREAD)
# 28     0.20                        (MILK, BREAD)
# 29     0.20                       (SUGER, BREAD)
# 30     0.20                         (TEA, BREAD)
# 31     0.15                       (COKE, COFFEE)
# 32     0.20                 (COFFEE, CORNFLAKES)
# 33     0.05                       (MILK, COFFEE)
# 34     0.20                      (SUGER, COFFEE)
# 35     0.05                        (TEA, COFFEE)
# 36     0.10                   (COKE, CORNFLAKES)
# 37     0.05                  (CORNFLAKES, MAGGI)
# 38     0.10                   (MILK, CORNFLAKES)
# 39     0.05                  (SUGER, CORNFLAKES)
# 40     0.10                    (TEA, CORNFLAKES)
# 41     0.10                         (JAM, MAGGI)
# 42     0.05                          (MILK, JAM)
# 43     0.05                           (TEA, JAM)
# 44     0.05                        (MILK, MAGGI)
# 45     0.20                         (TEA, MAGGI)
# 46     0.05                          (MILK, TEA)
# 47     0.05         (BISCUIT, CORNFLAKES, BREAD)
# 48     0.05              (BISCUIT, MAGGI, BREAD)
# 49     0.10               (BISCUIT, MILK, BREAD)
# 50     0.05              (SUGER, BISCUIT, BREAD)
# 51     0.05                (BISCUIT, TEA, BREAD)
# 52     0.10              (BISCUIT, COKE, COFFEE)
# 53     0.10        (BISCUIT, COFFEE, CORNFLAKES)
# 54     0.10          (BISCUIT, COKE, CORNFLAKES)
# 55     0.05          (BISCUIT, MILK, CORNFLAKES)
# 56     0.10                (BISCUIT, TEA, MAGGI)
# 57     0.05            (SUGER, BOURNVITA, BREAD)
# 58     0.10              (BOURNVITA, TEA, BREAD)
# 59     0.05           (SUGER, BOURNVITA, COFFEE)
# 60     0.05                (COKE, COFFEE, BREAD)
# 61     0.10               (SUGER, COFFEE, BREAD)
# 62     0.05            (MILK, CORNFLAKES, BREAD)
# 63     0.10                  (JAM, MAGGI, BREAD)
# 64     0.05                   (MILK, JAM, BREAD)
# 65     0.05                    (TEA, JAM, BREAD)
# 66     0.05                 (MILK, MAGGI, BREAD)
# 67     0.10                  (TEA, MAGGI, BREAD)
# 68     0.10           (COKE, COFFEE, CORNFLAKES)
# 69     0.05           (MILK, COFFEE, CORNFLAKES)
# 70     0.05          (SUGER, COFFEE, CORNFLAKES)
# 71     0.05            (TEA, COFFEE, CORNFLAKES)
# 72     0.05                  (MILK, TEA, COFFEE)
# 73     0.05             (TEA, CORNFLAKES, MAGGI)
# 74     0.05              (MILK, TEA, CORNFLAKES)
# 75     0.05                   (MILK, JAM, MAGGI)
# 76     0.05                    (TEA, MAGGI, JAM)
# 77     0.05   (BISCUIT, MILK, CORNFLAKES, BREAD)
# 78     0.05         (BISCUIT, TEA, MAGGI, BREAD)
# 79     0.10  (BISCUIT, COKE, COFFEE, CORNFLAKES)
# 80     0.05            (MILK, JAM, MAGGI, BREAD)
# 81     0.05             (TEA, MAGGI, JAM, BREAD)
# 82     0.05      (MILK, TEA, COFFEE, CORNFLAKES)

# %%
df1.sort_values(by="support",ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                             itemsets
# 2      0.65                              (BREAD)
# 3      0.40                             (COFFEE)
# 0      0.35                            (BISCUIT)
# 10     0.35                                (TEA)
# 5      0.30                         (CORNFLAKES)
# 9      0.30                              (SUGER)
# 7      0.25                              (MAGGI)
# 8      0.25                               (MILK)
# 34     0.20                      (SUGER, COFFEE)
# 28     0.20                        (MILK, BREAD)
# 45     0.20                         (TEA, MAGGI)
# 11     0.20                     (BISCUIT, BREAD)
# 1      0.20                          (BOURNVITA)
# 32     0.20                 (COFFEE, CORNFLAKES)
# 30     0.20                         (TEA, BREAD)
# 29     0.20                       (SUGER, BREAD)
# 27     0.15                       (MAGGI, BREAD)
# 19     0.15                   (BOURNVITA, BREAD)
# 23     0.15                      (COFFEE, BREAD)
# 31     0.15                       (COKE, COFFEE)
# 14     0.15                (BISCUIT, CORNFLAKES)
# 4      0.15                               (COKE)
# 49     0.10               (BISCUIT, MILK, BREAD)
# 40     0.10                    (TEA, CORNFLAKES)
# 56     0.10                (BISCUIT, TEA, MAGGI)
# 52     0.10              (BISCUIT, COKE, COFFEE)
# 53     0.10        (BISCUIT, COFFEE, CORNFLAKES)
# 54     0.10          (BISCUIT, COKE, CORNFLAKES)
# 36     0.10                   (COKE, CORNFLAKES)
# 58     0.10              (BOURNVITA, TEA, BREAD)
# 61     0.10               (SUGER, COFFEE, BREAD)
# 63     0.10                  (JAM, MAGGI, BREAD)
# 67     0.10                  (TEA, MAGGI, BREAD)
# 68     0.10           (COKE, COFFEE, CORNFLAKES)
# 79     0.10  (BISCUIT, COKE, COFFEE, CORNFLAKES)
# 38     0.10                   (MILK, CORNFLAKES)
# 41     0.10                         (JAM, MAGGI)
# 16     0.10                      (BISCUIT, MILK)
# 26     0.10                         (JAM, BREAD)
# 6      0.10                                (JAM)
# 13     0.10                      (BISCUIT, COKE)
# 18     0.10                       (BISCUIT, TEA)
# 12     0.10                    (BISCUIT, COFFEE)
# 21     0.10                   (SUGER, BOURNVITA)
# 15     0.10                     (BISCUIT, MAGGI)
# 22     0.10                     (BOURNVITA, TEA)
# 70     0.05          (SUGER, COFFEE, CORNFLAKES)
# 64     0.05                   (MILK, JAM, BREAD)
# 65     0.05                    (TEA, JAM, BREAD)
# 66     0.05                 (MILK, MAGGI, BREAD)
# 69     0.05           (MILK, COFFEE, CORNFLAKES)
# 37     0.05                  (CORNFLAKES, MAGGI)
# 71     0.05            (TEA, COFFEE, CORNFLAKES)
# 73     0.05             (TEA, CORNFLAKES, MAGGI)
# 74     0.05              (MILK, TEA, CORNFLAKES)
# 75     0.05                   (MILK, JAM, MAGGI)
# 76     0.05                    (TEA, MAGGI, JAM)
# 77     0.05   (BISCUIT, MILK, CORNFLAKES, BREAD)
# 78     0.05         (BISCUIT, TEA, MAGGI, BREAD)
# 80     0.05            (MILK, JAM, MAGGI, BREAD)
# 81     0.05             (TEA, MAGGI, JAM, BREAD)
# 72     0.05                  (MILK, TEA, COFFEE)
# 60     0.05                (COKE, COFFEE, BREAD)
# 62     0.05            (MILK, CORNFLAKES, BREAD)
# 35     0.05                        (TEA, COFFEE)
# 39     0.05                  (SUGER, CORNFLAKES)
# 33     0.05                       (MILK, COFFEE)
# 42     0.05                          (MILK, JAM)
# 43     0.05                           (TEA, JAM)
# 44     0.05                        (MILK, MAGGI)
# 25     0.05                  (CORNFLAKES, BREAD)
# 46     0.05                          (MILK, TEA)
# 47     0.05         (BISCUIT, CORNFLAKES, BREAD)
# 48     0.05              (BISCUIT, MAGGI, BREAD)
# 24     0.05                        (COKE, BREAD)
# 50     0.05              (SUGER, BISCUIT, BREAD)
# 51     0.05                (BISCUIT, TEA, BREAD)
# 20     0.05                  (BOURNVITA, COFFEE)
# 55     0.05          (BISCUIT, MILK, CORNFLAKES)
# 57     0.05            (SUGER, BOURNVITA, BREAD)
# 17     0.05                     (SUGER, BISCUIT)
# 59     0.05           (SUGER, BOURNVITA, COFFEE)
# 82     0.05      (MILK, TEA, COFFEE, CORNFLAKES)

# %%
df1['length'] = df1['itemsets'].apply(lambda x:len(x))
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support                             itemsets  length
# 0      0.35                            (BISCUIT)       1
# 1      0.20                          (BOURNVITA)       1
# 2      0.65                              (BREAD)       1
# 3      0.40                             (COFFEE)       1
# 4      0.15                               (COKE)       1
# 5      0.30                         (CORNFLAKES)       1
# 6      0.10                                (JAM)       1
# 7      0.25                              (MAGGI)       1
# 8      0.25                               (MILK)       1
# 9      0.30                              (SUGER)       1
# 10     0.35                                (TEA)       1
# 11     0.20                     (BISCUIT, BREAD)       2
# 12     0.10                    (BISCUIT, COFFEE)       2
# 13     0.10                      (BISCUIT, COKE)       2
# 14     0.15                (BISCUIT, CORNFLAKES)       2
# 15     0.10                     (BISCUIT, MAGGI)       2
# 16     0.10                      (BISCUIT, MILK)       2
# 17     0.05                     (SUGER, BISCUIT)       2
# 18     0.10                       (BISCUIT, TEA)       2
# 19     0.15                   (BOURNVITA, BREAD)       2
# 20     0.05                  (BOURNVITA, COFFEE)       2
# 21     0.10                   (SUGER, BOURNVITA)       2
# 22     0.10                     (BOURNVITA, TEA)       2
# 23     0.15                      (COFFEE, BREAD)       2
# 24     0.05                        (COKE, BREAD)       2
# 25     0.05                  (CORNFLAKES, BREAD)       2
# 26     0.10                         (JAM, BREAD)       2
# 27     0.15                       (MAGGI, BREAD)       2
# 28     0.20                        (MILK, BREAD)       2
# 29     0.20                       (SUGER, BREAD)       2
# 30     0.20                         (TEA, BREAD)       2
# 31     0.15                       (COKE, COFFEE)       2
# 32     0.20                 (COFFEE, CORNFLAKES)       2
# 33     0.05                       (MILK, COFFEE)       2
# 34     0.20                      (SUGER, COFFEE)       2
# 35     0.05                        (TEA, COFFEE)       2
# 36     0.10                   (COKE, CORNFLAKES)       2
# 37     0.05                  (CORNFLAKES, MAGGI)       2
# 38     0.10                   (MILK, CORNFLAKES)       2
# 39     0.05                  (SUGER, CORNFLAKES)       2
# 40     0.10                    (TEA, CORNFLAKES)       2
# 41     0.10                         (JAM, MAGGI)       2
# 42     0.05                          (MILK, JAM)       2
# 43     0.05                           (TEA, JAM)       2
# 44     0.05                        (MILK, MAGGI)       2
# 45     0.20                         (TEA, MAGGI)       2
# 46     0.05                          (MILK, TEA)       2
# 47     0.05         (BISCUIT, CORNFLAKES, BREAD)       3
# 48     0.05              (BISCUIT, MAGGI, BREAD)       3
# 49     0.10               (BISCUIT, MILK, BREAD)       3
# 50     0.05              (SUGER, BISCUIT, BREAD)       3
# 51     0.05                (BISCUIT, TEA, BREAD)       3
# 52     0.10              (BISCUIT, COKE, COFFEE)       3
# 53     0.10        (BISCUIT, COFFEE, CORNFLAKES)       3
# 54     0.10          (BISCUIT, COKE, CORNFLAKES)       3
# 55     0.05          (BISCUIT, MILK, CORNFLAKES)       3
# 56     0.10                (BISCUIT, TEA, MAGGI)       3
# 57     0.05            (SUGER, BOURNVITA, BREAD)       3
# 58     0.10              (BOURNVITA, TEA, BREAD)       3
# 59     0.05           (SUGER, BOURNVITA, COFFEE)       3
# 60     0.05                (COKE, COFFEE, BREAD)       3
# 61     0.10               (SUGER, COFFEE, BREAD)       3
# 62     0.05            (MILK, CORNFLAKES, BREAD)       3
# 63     0.10                  (JAM, MAGGI, BREAD)       3
# 64     0.05                   (MILK, JAM, BREAD)       3
# 65     0.05                    (TEA, JAM, BREAD)       3
# 66     0.05                 (MILK, MAGGI, BREAD)       3
# 67     0.10                  (TEA, MAGGI, BREAD)       3
# 68     0.10           (COKE, COFFEE, CORNFLAKES)       3
# 69     0.05           (MILK, COFFEE, CORNFLAKES)       3
# 70     0.05          (SUGER, COFFEE, CORNFLAKES)       3
# 71     0.05            (TEA, COFFEE, CORNFLAKES)       3
# 72     0.05                  (MILK, TEA, COFFEE)       3
# 73     0.05             (TEA, CORNFLAKES, MAGGI)       3
# 74     0.05              (MILK, TEA, CORNFLAKES)       3
# 75     0.05                   (MILK, JAM, MAGGI)       3
# 76     0.05                    (TEA, MAGGI, JAM)       3
# 77     0.05   (BISCUIT, MILK, CORNFLAKES, BREAD)       4
# 78     0.05         (BISCUIT, TEA, MAGGI, BREAD)       4
# 79     0.10  (BISCUIT, COKE, COFFEE, CORNFLAKES)       4
# 80     0.05            (MILK, JAM, MAGGI, BREAD)       4
# 81     0.05             (TEA, MAGGI, JAM, BREAD)       4
# 82     0.05      (MILK, TEA, COFFEE, CORNFLAKES)       4

# %%
df1[(df1['length']==2) & (df1['support']>=0.15)]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support               itemsets  length
# 11     0.20       (BISCUIT, BREAD)       2
# 14     0.15  (BISCUIT, CORNFLAKES)       2
# 19     0.15     (BOURNVITA, BREAD)       2
# 23     0.15        (COFFEE, BREAD)       2
# 27     0.15         (MAGGI, BREAD)       2
# 28     0.20          (MILK, BREAD)       2
# 29     0.20         (SUGER, BREAD)       2
# 30     0.20           (TEA, BREAD)       2
# 31     0.15         (COKE, COFFEE)       2
# 32     0.20   (COFFEE, CORNFLAKES)       2
# 34     0.20        (SUGER, COFFEE)       2
# 45     0.20           (TEA, MAGGI)       2

# %%
from mlxtend.frequent_patterns import association_rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Association Rules & Info
df_ar = association_rules(df1, metric = "confidence", min_threshold = 0.5)
df_ar
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                        antecedents                    consequents  \
# 0                        (BISCUIT)                        (BREAD)
# 1                           (COKE)                      (BISCUIT)
# 2                     (CORNFLAKES)                      (BISCUIT)
# 3                      (BOURNVITA)                        (BREAD)
# 4                      (BOURNVITA)                        (SUGER)
# 5                      (BOURNVITA)                          (TEA)
# 6                            (JAM)                        (BREAD)
# 7                          (MAGGI)                        (BREAD)
# 8                           (MILK)                        (BREAD)
# 9                          (SUGER)                        (BREAD)
# 10                           (TEA)                        (BREAD)
# 11                          (COKE)                       (COFFEE)
# 12                        (COFFEE)                   (CORNFLAKES)
# 13                    (CORNFLAKES)                       (COFFEE)
# 14                         (SUGER)                       (COFFEE)
# 15                        (COFFEE)                        (SUGER)
# 16                          (COKE)                   (CORNFLAKES)
# 17                           (JAM)                        (MAGGI)
# 18                           (JAM)                         (MILK)
# 19                           (JAM)                          (TEA)
# 20                           (TEA)                        (MAGGI)
# 21                         (MAGGI)                          (TEA)
# 22             (CORNFLAKES, BREAD)                      (BISCUIT)
# 23                (BISCUIT, MAGGI)                        (BREAD)
# 24                 (BISCUIT, MILK)                        (BREAD)
# 25                (BISCUIT, BREAD)                         (MILK)
# 26                   (MILK, BREAD)                      (BISCUIT)
# 27                (SUGER, BISCUIT)                        (BREAD)
# 28                  (BISCUIT, TEA)                        (BREAD)
# 29                 (BISCUIT, COKE)                       (COFFEE)
# 30               (BISCUIT, COFFEE)                         (COKE)
# 31                  (COKE, COFFEE)                      (BISCUIT)
# 32                          (COKE)              (BISCUIT, COFFEE)
# 33               (BISCUIT, COFFEE)                   (CORNFLAKES)
# 34           (BISCUIT, CORNFLAKES)                       (COFFEE)
# 35            (COFFEE, CORNFLAKES)                      (BISCUIT)
# 36                 (BISCUIT, COKE)                   (CORNFLAKES)
# 37           (BISCUIT, CORNFLAKES)                         (COKE)
# 38              (COKE, CORNFLAKES)                      (BISCUIT)
# 39                          (COKE)          (BISCUIT, CORNFLAKES)
# 40                 (BISCUIT, MILK)                   (CORNFLAKES)
# 41              (MILK, CORNFLAKES)                      (BISCUIT)
# 42                  (BISCUIT, TEA)                        (MAGGI)
# 43                (BISCUIT, MAGGI)                          (TEA)
# 44                    (TEA, MAGGI)                      (BISCUIT)
# 45              (SUGER, BOURNVITA)                        (BREAD)
# 46                (BOURNVITA, TEA)                        (BREAD)
# 47              (BOURNVITA, BREAD)                          (TEA)
# 48                    (TEA, BREAD)                    (BOURNVITA)
# 49                     (BOURNVITA)                   (TEA, BREAD)
# 50              (SUGER, BOURNVITA)                       (COFFEE)
# 51             (BOURNVITA, COFFEE)                        (SUGER)
# 52                   (COKE, BREAD)                       (COFFEE)
# 53                 (SUGER, COFFEE)                        (BREAD)
# 54                  (SUGER, BREAD)                       (COFFEE)
# 55                 (COFFEE, BREAD)                        (SUGER)
# 56              (MILK, CORNFLAKES)                        (BREAD)
# 57             (CORNFLAKES, BREAD)                         (MILK)
# 58                    (JAM, MAGGI)                        (BREAD)
# 59                    (JAM, BREAD)                        (MAGGI)
# 60                  (MAGGI, BREAD)                          (JAM)
# 61                           (JAM)                 (MAGGI, BREAD)
# 62                     (MILK, JAM)                        (BREAD)
# 63                    (JAM, BREAD)                         (MILK)
# 64                           (JAM)                  (MILK, BREAD)
# 65                      (TEA, JAM)                        (BREAD)
# 66                    (JAM, BREAD)                          (TEA)
# 67                           (JAM)                   (TEA, BREAD)
# 68                   (MILK, MAGGI)                        (BREAD)
# 69                    (TEA, MAGGI)                        (BREAD)
# 70                    (TEA, BREAD)                        (MAGGI)
# 71                  (MAGGI, BREAD)                          (TEA)
# 72                  (COKE, COFFEE)                   (CORNFLAKES)
# 73              (COKE, CORNFLAKES)                       (COFFEE)
# 74            (COFFEE, CORNFLAKES)                         (COKE)
# 75                          (COKE)           (COFFEE, CORNFLAKES)
# 76                  (MILK, COFFEE)                   (CORNFLAKES)
# 77              (MILK, CORNFLAKES)                       (COFFEE)
# 78             (SUGER, CORNFLAKES)                       (COFFEE)
# 79                   (TEA, COFFEE)                   (CORNFLAKES)
# 80               (TEA, CORNFLAKES)                       (COFFEE)
# 81                     (MILK, TEA)                       (COFFEE)
# 82                  (MILK, COFFEE)                          (TEA)
# 83                   (TEA, COFFEE)                         (MILK)
# 84               (TEA, CORNFLAKES)                        (MAGGI)
# 85             (CORNFLAKES, MAGGI)                          (TEA)
# 86                     (MILK, TEA)                   (CORNFLAKES)
# 87              (MILK, CORNFLAKES)                          (TEA)
# 88               (TEA, CORNFLAKES)                         (MILK)
# 89                     (MILK, JAM)                        (MAGGI)
# 90                   (MILK, MAGGI)                          (JAM)
# 91                    (JAM, MAGGI)                         (MILK)
# 92                           (JAM)                  (MILK, MAGGI)
# 93                      (TEA, JAM)                        (MAGGI)
# 94                    (JAM, MAGGI)                          (TEA)
# 95                           (JAM)                   (TEA, MAGGI)
# 96     (BISCUIT, MILK, CORNFLAKES)                        (BREAD)
# 97          (BISCUIT, MILK, BREAD)                   (CORNFLAKES)
# 98    (BISCUIT, CORNFLAKES, BREAD)                         (MILK)
# 99       (MILK, CORNFLAKES, BREAD)                      (BISCUIT)
# 100                (BISCUIT, MILK)            (CORNFLAKES, BREAD)
# 101             (MILK, CORNFLAKES)               (BISCUIT, BREAD)
# 102            (CORNFLAKES, BREAD)                (BISCUIT, MILK)
# 103          (BISCUIT, TEA, MAGGI)                        (BREAD)
# 104          (BISCUIT, TEA, BREAD)                        (MAGGI)
# 105        (BISCUIT, MAGGI, BREAD)                          (TEA)
# 106            (TEA, MAGGI, BREAD)                      (BISCUIT)
# 107                 (BISCUIT, TEA)                 (MAGGI, BREAD)
# 108               (BISCUIT, MAGGI)                   (TEA, BREAD)
# 109        (BISCUIT, COKE, COFFEE)                   (CORNFLAKES)
# 110    (BISCUIT, COKE, CORNFLAKES)                       (COFFEE)
# 111  (BISCUIT, COFFEE, CORNFLAKES)                         (COKE)
# 112     (COKE, COFFEE, CORNFLAKES)                      (BISCUIT)
# 113                (BISCUIT, COKE)           (COFFEE, CORNFLAKES)
# 114              (BISCUIT, COFFEE)             (COKE, CORNFLAKES)
# 115          (BISCUIT, CORNFLAKES)                 (COKE, COFFEE)
# 116                 (COKE, COFFEE)          (BISCUIT, CORNFLAKES)
# 117             (COKE, CORNFLAKES)              (BISCUIT, COFFEE)
# 118           (COFFEE, CORNFLAKES)                (BISCUIT, COKE)
# 119                         (COKE)  (BISCUIT, COFFEE, CORNFLAKES)
# 120             (MILK, JAM, MAGGI)                        (BREAD)
# 121             (MILK, JAM, BREAD)                        (MAGGI)
# 122           (MILK, MAGGI, BREAD)                          (JAM)
# 123            (JAM, MAGGI, BREAD)                         (MILK)
# 124                    (MILK, JAM)                 (MAGGI, BREAD)
# 125                  (MILK, MAGGI)                   (JAM, BREAD)
# 126                   (JAM, MAGGI)                  (MILK, BREAD)
# 127                   (JAM, BREAD)                  (MILK, MAGGI)
# 128                          (JAM)           (MILK, MAGGI, BREAD)
# 129              (JAM, TEA, MAGGI)                        (BREAD)
# 130            (TEA, MAGGI, BREAD)                          (JAM)
# 131              (TEA, JAM, BREAD)                        (MAGGI)
# 132            (JAM, MAGGI, BREAD)                          (TEA)
# 133                     (TEA, JAM)                 (MAGGI, BREAD)
# 134                   (JAM, MAGGI)                   (TEA, BREAD)
# 135                   (JAM, BREAD)                   (TEA, MAGGI)
# 136                          (JAM)            (TEA, MAGGI, BREAD)
# 137            (MILK, TEA, COFFEE)                   (CORNFLAKES)
# 138        (MILK, TEA, CORNFLAKES)                       (COFFEE)
# 139     (MILK, COFFEE, CORNFLAKES)                          (TEA)
# 140      (TEA, COFFEE, CORNFLAKES)                         (MILK)
# 141                    (MILK, TEA)           (COFFEE, CORNFLAKES)
# 142                 (MILK, COFFEE)              (TEA, CORNFLAKES)
# 143             (MILK, CORNFLAKES)                  (TEA, COFFEE)
# 144                  (TEA, COFFEE)             (MILK, CORNFLAKES)
# 145              (TEA, CORNFLAKES)                 (MILK, COFFEE)
#
#      antecedent support  consequent support  support  confidence       lift  \
# 0                  0.35                0.65     0.20    0.571429   0.879121
# 1                  0.15                0.35     0.10    0.666667   1.904762
# 2                  0.30                0.35     0.15    0.500000   1.428571
# 3                  0.20                0.65     0.15    0.750000   1.153846
# 4                  0.20                0.30     0.10    0.500000   1.666667
# 5                  0.20                0.35     0.10    0.500000   1.428571
# 6                  0.10                0.65     0.10    1.000000   1.538462
# 7                  0.25                0.65     0.15    0.600000   0.923077
# 8                  0.25                0.65     0.20    0.800000   1.230769
# 9                  0.30                0.65     0.20    0.666667   1.025641
# 10                 0.35                0.65     0.20    0.571429   0.879121
# 11                 0.15                0.40     0.15    1.000000   2.500000
# 12                 0.40                0.30     0.20    0.500000   1.666667
# 13                 0.30                0.40     0.20    0.666667   1.666667
# 14                 0.30                0.40     0.20    0.666667   1.666667
# 15                 0.40                0.30     0.20    0.500000   1.666667
# 16                 0.15                0.30     0.10    0.666667   2.222222
# 17                 0.10                0.25     0.10    1.000000   4.000000
# 18                 0.10                0.25     0.05    0.500000   2.000000
# 19                 0.10                0.35     0.05    0.500000   1.428571
# 20                 0.35                0.25     0.20    0.571429   2.285714
# 21                 0.25                0.35     0.20    0.800000   2.285714
# 22                 0.05                0.35     0.05    1.000000   2.857143
# 23                 0.10                0.65     0.05    0.500000   0.769231
# 24                 0.10                0.65     0.10    1.000000   1.538462
# 25                 0.20                0.25     0.10    0.500000   2.000000
# 26                 0.20                0.35     0.10    0.500000   1.428571
# 27                 0.05                0.65     0.05    1.000000   1.538462
# 28                 0.10                0.65     0.05    0.500000   0.769231
# 29                 0.10                0.40     0.10    1.000000   2.500000
# 30                 0.10                0.15     0.10    1.000000   6.666667
# 31                 0.15                0.35     0.10    0.666667   1.904762
# 32                 0.15                0.10     0.10    0.666667   6.666667
# 33                 0.10                0.30     0.10    1.000000   3.333333
# 34                 0.15                0.40     0.10    0.666667   1.666667
# 35                 0.20                0.35     0.10    0.500000   1.428571
# 36                 0.10                0.30     0.10    1.000000   3.333333
# 37                 0.15                0.15     0.10    0.666667   4.444444
# 38                 0.10                0.35     0.10    1.000000   2.857143
# 39                 0.15                0.15     0.10    0.666667   4.444444
# 40                 0.10                0.30     0.05    0.500000   1.666667
# 41                 0.10                0.35     0.05    0.500000   1.428571
# 42                 0.10                0.25     0.10    1.000000   4.000000
# 43                 0.10                0.35     0.10    1.000000   2.857143
# 44                 0.20                0.35     0.10    0.500000   1.428571
# 45                 0.10                0.65     0.05    0.500000   0.769231
# 46                 0.10                0.65     0.10    1.000000   1.538462
# 47                 0.15                0.35     0.10    0.666667   1.904762
# 48                 0.20                0.20     0.10    0.500000   2.500000
# 49                 0.20                0.20     0.10    0.500000   2.500000
# 50                 0.10                0.40     0.05    0.500000   1.250000
# 51                 0.05                0.30     0.05    1.000000   3.333333
# 52                 0.05                0.40     0.05    1.000000   2.500000
# 53                 0.20                0.65     0.10    0.500000   0.769231
# 54                 0.20                0.40     0.10    0.500000   1.250000
# 55                 0.15                0.30     0.10    0.666667   2.222222
# 56                 0.10                0.65     0.05    0.500000   0.769231
# 57                 0.05                0.25     0.05    1.000000   4.000000
# 58                 0.10                0.65     0.10    1.000000   1.538462
# 59                 0.10                0.25     0.10    1.000000   4.000000
# 60                 0.15                0.10     0.10    0.666667   6.666667
# 61                 0.10                0.15     0.10    1.000000   6.666667
# 62                 0.05                0.65     0.05    1.000000   1.538462
# 63                 0.10                0.25     0.05    0.500000   2.000000
# 64                 0.10                0.20     0.05    0.500000   2.500000
# 65                 0.05                0.65     0.05    1.000000   1.538462
# 66                 0.10                0.35     0.05    0.500000   1.428571
# 67                 0.10                0.20     0.05    0.500000   2.500000
# 68                 0.05                0.65     0.05    1.000000   1.538462
# 69                 0.20                0.65     0.10    0.500000   0.769231
# 70                 0.20                0.25     0.10    0.500000   2.000000
# 71                 0.15                0.35     0.10    0.666667   1.904762
# 72                 0.15                0.30     0.10    0.666667   2.222222
# 73                 0.10                0.40     0.10    1.000000   2.500000
# 74                 0.20                0.15     0.10    0.500000   3.333333
# 75                 0.15                0.20     0.10    0.666667   3.333333
# 76                 0.05                0.30     0.05    1.000000   3.333333
# 77                 0.10                0.40     0.05    0.500000   1.250000
# 78                 0.05                0.40     0.05    1.000000   2.500000
# 79                 0.05                0.30     0.05    1.000000   3.333333
# 80                 0.10                0.40     0.05    0.500000   1.250000
# 81                 0.05                0.40     0.05    1.000000   2.500000
# 82                 0.05                0.35     0.05    1.000000   2.857143
# 83                 0.05                0.25     0.05    1.000000   4.000000
# 84                 0.10                0.25     0.05    0.500000   2.000000
# 85                 0.05                0.35     0.05    1.000000   2.857143
# 86                 0.05                0.30     0.05    1.000000   3.333333
# 87                 0.10                0.35     0.05    0.500000   1.428571
# 88                 0.10                0.25     0.05    0.500000   2.000000
# 89                 0.05                0.25     0.05    1.000000   4.000000
# 90                 0.05                0.10     0.05    1.000000  10.000000
# 91                 0.10                0.25     0.05    0.500000   2.000000
# 92                 0.10                0.05     0.05    0.500000  10.000000
# 93                 0.05                0.25     0.05    1.000000   4.000000
# 94                 0.10                0.35     0.05    0.500000   1.428571
# 95                 0.10                0.20     0.05    0.500000   2.500000
# 96                 0.05                0.65     0.05    1.000000   1.538462
# 97                 0.10                0.30     0.05    0.500000   1.666667
# 98                 0.05                0.25     0.05    1.000000   4.000000
# 99                 0.05                0.35     0.05    1.000000   2.857143
# 100                0.10                0.05     0.05    0.500000  10.000000
# 101                0.10                0.20     0.05    0.500000   2.500000
# 102                0.05                0.10     0.05    1.000000  10.000000
# 103                0.10                0.65     0.05    0.500000   0.769231
# 104                0.05                0.25     0.05    1.000000   4.000000
# 105                0.05                0.35     0.05    1.000000   2.857143
# 106                0.10                0.35     0.05    0.500000   1.428571
# 107                0.10                0.15     0.05    0.500000   3.333333
# 108                0.10                0.20     0.05    0.500000   2.500000
# 109                0.10                0.30     0.10    1.000000   3.333333
# 110                0.10                0.40     0.10    1.000000   2.500000
# 111                0.10                0.15     0.10    1.000000   6.666667
# 112                0.10                0.35     0.10    1.000000   2.857143
# 113                0.10                0.20     0.10    1.000000   5.000000
# 114                0.10                0.10     0.10    1.000000  10.000000
# 115                0.15                0.15     0.10    0.666667   4.444444
# 116                0.15                0.15     0.10    0.666667   4.444444
# 117                0.10                0.10     0.10    1.000000  10.000000
# 118                0.20                0.10     0.10    0.500000   5.000000
# 119                0.15                0.10     0.10    0.666667   6.666667
# 120                0.05                0.65     0.05    1.000000   1.538462
# 121                0.05                0.25     0.05    1.000000   4.000000
# 122                0.05                0.10     0.05    1.000000  10.000000
# 123                0.10                0.25     0.05    0.500000   2.000000
# 124                0.05                0.15     0.05    1.000000   6.666667
# 125                0.05                0.10     0.05    1.000000  10.000000
# 126                0.10                0.20     0.05    0.500000   2.500000
# 127                0.10                0.05     0.05    0.500000  10.000000
# 128                0.10                0.05     0.05    0.500000  10.000000
# 129                0.05                0.65     0.05    1.000000   1.538462
# 130                0.10                0.10     0.05    0.500000   5.000000
# 131                0.05                0.25     0.05    1.000000   4.000000
# 132                0.10                0.35     0.05    0.500000   1.428571
# 133                0.05                0.15     0.05    1.000000   6.666667
# 134                0.10                0.20     0.05    0.500000   2.500000
# 135                0.10                0.20     0.05    0.500000   2.500000
# 136                0.10                0.10     0.05    0.500000   5.000000
# 137                0.05                0.30     0.05    1.000000   3.333333
# 138                0.05                0.40     0.05    1.000000   2.500000
# 139                0.05                0.35     0.05    1.000000   2.857143
# 140                0.05                0.25     0.05    1.000000   4.000000
# 141                0.05                0.20     0.05    1.000000   5.000000
# 142                0.05                0.10     0.05    1.000000  10.000000
# 143                0.10                0.05     0.05    0.500000  10.000000
# 144                0.05                0.10     0.05    1.000000  10.000000
# 145                0.10                0.05     0.05    0.500000  10.000000
#
#      leverage  conviction  zhangs_metric
# 0     -0.0275    0.816667      -0.174603
# 1      0.0475    1.950000       0.558824
# 2      0.0450    1.300000       0.428571
# 3      0.0200    1.400000       0.166667
# 4      0.0400    1.400000       0.500000
# 5      0.0300    1.300000       0.375000
# 6      0.0350         inf       0.388889
# 7     -0.0125    0.875000      -0.100000
# 8      0.0375    1.750000       0.250000
# 9      0.0050    1.050000       0.035714
# 10    -0.0275    0.816667      -0.174603
# 11     0.0900         inf       0.705882
# 12     0.0800    1.400000       0.666667
# 13     0.0800    1.800000       0.571429
# 14     0.0800    1.800000       0.571429
# 15     0.0800    1.400000       0.666667
# 16     0.0550    2.100000       0.647059
# 17     0.0750         inf       0.833333
# 18     0.0250    1.500000       0.555556
# 19     0.0150    1.300000       0.333333
# 20     0.1125    1.750000       0.865385
# 21     0.1125    3.250000       0.750000
# 22     0.0325         inf       0.684211
# 23    -0.0150    0.700000      -0.250000
# 24     0.0350         inf       0.388889
# 25     0.0500    1.500000       0.625000
# 26     0.0300    1.300000       0.375000
# 27     0.0175         inf       0.368421
# 28    -0.0150    0.700000      -0.250000
# 29     0.0600         inf       0.666667
# 30     0.0850         inf       0.944444
# 31     0.0475    1.950000       0.558824
# 32     0.0850    2.700000       1.000000
# 33     0.0700         inf       0.777778
# 34     0.0400    1.800000       0.470588
# 35     0.0300    1.300000       0.375000
# 36     0.0700         inf       0.777778
# 37     0.0775    2.550000       0.911765
# 38     0.0650         inf       0.722222
# 39     0.0775    2.550000       0.911765
# 40     0.0200    1.400000       0.444444
# 41     0.0150    1.300000       0.333333
# 42     0.0750         inf       0.833333
# 43     0.0650         inf       0.722222
# 44     0.0300    1.300000       0.375000
# 45    -0.0150    0.700000      -0.250000
# 46     0.0350         inf       0.388889
# 47     0.0475    1.950000       0.558824
# 48     0.0600    1.600000       0.750000
# 49     0.0600    1.600000       0.750000
# 50     0.0100    1.200000       0.222222
# 51     0.0350         inf       0.736842
# 52     0.0300         inf       0.631579
# 53    -0.0300    0.700000      -0.272727
# 54     0.0200    1.200000       0.250000
# 55     0.0550    2.100000       0.647059
# 56    -0.0150    0.700000      -0.250000
# 57     0.0375         inf       0.789474
# 58     0.0350         inf       0.388889
# 59     0.0750         inf       0.833333
# 60     0.0850    2.700000       1.000000
# 61     0.0850         inf       0.944444
# 62     0.0175         inf       0.368421
# 63     0.0250    1.500000       0.555556
# 64     0.0300    1.600000       0.666667
# 65     0.0175         inf       0.368421
# 66     0.0150    1.300000       0.333333
# 67     0.0300    1.600000       0.666667
# 68     0.0175         inf       0.368421
# 69    -0.0300    0.700000      -0.272727
# 70     0.0500    1.500000       0.625000
# 71     0.0475    1.950000       0.558824
# 72     0.0550    2.100000       0.647059
# 73     0.0600         inf       0.666667
# 74     0.0700    1.700000       0.875000
# 75     0.0700    2.400000       0.823529
# 76     0.0350         inf       0.736842
# 77     0.0100    1.200000       0.222222
# 78     0.0300         inf       0.631579
# 79     0.0350         inf       0.736842
# 80     0.0100    1.200000       0.222222
# 81     0.0300         inf       0.631579
# 82     0.0325         inf       0.684211
# 83     0.0375         inf       0.789474
# 84     0.0250    1.500000       0.555556
# 85     0.0325         inf       0.684211
# 86     0.0350         inf       0.736842
# 87     0.0150    1.300000       0.333333
# 88     0.0250    1.500000       0.555556
# 89     0.0375         inf       0.789474
# 90     0.0450         inf       0.947368
# 91     0.0250    1.500000       0.555556
# 92     0.0450    1.900000       1.000000
# 93     0.0375         inf       0.789474
# 94     0.0150    1.300000       0.333333
# 95     0.0300    1.600000       0.666667
# 96     0.0175         inf       0.368421
# 97     0.0200    1.400000       0.444444
# 98     0.0375         inf       0.789474
# 99     0.0325         inf       0.684211
# 100    0.0450    1.900000       1.000000
# 101    0.0300    1.600000       0.666667
# 102    0.0450         inf       0.947368
# 103   -0.0150    0.700000      -0.250000
# 104    0.0375         inf       0.789474
# 105    0.0325         inf       0.684211
# 106    0.0150    1.300000       0.333333
# 107    0.0350    1.700000       0.777778
# 108    0.0300    1.600000       0.666667
# 109    0.0700         inf       0.777778
# 110    0.0600         inf       0.666667
# 111    0.0850         inf       0.944444
# 112    0.0650         inf       0.722222
# 113    0.0800         inf       0.888889
# 114    0.0900         inf       1.000000
# 115    0.0775    2.550000       0.911765
# 116    0.0775    2.550000       0.911765
# 117    0.0900         inf       1.000000
# 118    0.0800    1.800000       1.000000
# 119    0.0850    2.700000       1.000000
# 120    0.0175         inf       0.368421
# 121    0.0375         inf       0.789474
# 122    0.0450         inf       0.947368
# 123    0.0250    1.500000       0.555556
# 124    0.0425         inf       0.894737
# 125    0.0450         inf       0.947368
# 126    0.0300    1.600000       0.666667
# 127    0.0450    1.900000       1.000000
# 128    0.0450    1.900000       1.000000
# 129    0.0175         inf       0.368421
# 130    0.0400    1.800000       0.888889
# 131    0.0375         inf       0.789474
# 132    0.0150    1.300000       0.333333
# 133    0.0425         inf       0.894737
# 134    0.0300    1.600000       0.666667
# 135    0.0300    1.600000       0.666667
# 136    0.0400    1.800000       0.888889
# 137    0.0350         inf       0.736842
# 138    0.0300         inf       0.631579
# 139    0.0325         inf       0.684211
# 140    0.0375         inf       0.789474
# 141    0.0400         inf       0.842105
# 142    0.0450         inf       0.947368
# 143    0.0450    1.900000       1.000000
# 144    0.0450         inf       0.947368
# 145    0.0450    1.900000       1.000000

# %% [markdown]
# * Antecedent support variable tells us probability of antecedent products alone
# * Consequents support variable tells us probability of consequents products alone
# * The support value is the value of the two products (Antecedents and Consequents)
# * Confidence is an indication of how often the rule has been found to be true.
# * The ratio of the observed support to that expected if X and Y were independent.

# %% [markdown]
# **Lift indicates:**
#
# 1. Whether if two type of products can be sold together - lift value higher than 1
# 2. Whether 1 product be substitute of other - lift value lower than 1
# 3. Whether if there is no relation between the type or products - lift value equals to 1

# %%
df_ar[(df_ar.support > 0.15) & (df_ar.confidence > 0.70)].sort_values("confidence", ascending = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    antecedents consequents  antecedent support  consequent support  support  \
# 8       (MILK)     (BREAD)                0.25                0.65      0.2
# 21     (MAGGI)       (TEA)                0.25                0.35      0.2
#
#     confidence      lift  leverage  conviction  zhangs_metric
# 8          0.8  1.230769    0.0375        1.75           0.25
# 21         0.8  2.285714    0.1125        3.25           0.75

# %% [markdown]
# **For MILK-BREAD pair:** antecedent support=0.25: Milk is observed in 25% of all the purchases. consequent support=0.65: Bread is observed 65% of all the purchases. support=0.20 : Milk and Bread are observed together in 20% of all purchases. confidence=0.8: If Milk is bought, Bread is 80% likely to be bought as well. Lift=1.23: That means Milk and Bread affects each other's sales positively. Sales of Bread increase by 1.23 times in transactions which contains Milk or visa versa.
#
# **For MAGGI-TEA pair:** antecedent support=0.25: Maggi is observed in 25% of all the purchases. consequent support=0.35: Tea is observed 35% of all the purchases. support=0.20 : Maggi and Tea are observed together in 20% of all purchases. confidence=0.8: If Maggi is bought, Tea is 80% likely to be bought as well. Lift=2.286: That means Maggi and Tea affects each other's sales positively. Sales of Maggi increase by 2.286 times in transactions which contains Tea or visa versa.

# %%
df_lift = association_rules(df1, metric = 'lift', min_threshold = 1)
# displaying results with lift >= 1
df_lift.sort_values(by = 'lift', ascending = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                        antecedents                    consequents  \
# 228                   (JAM, BREAD)                  (MILK, MAGGI)
# 254             (MILK, CORNFLAKES)                  (TEA, COFFEE)
# 231                          (JAM)           (MILK, MAGGI, BREAD)
# 222           (MILK, MAGGI, BREAD)                          (JAM)
# 211              (BISCUIT, COFFEE)             (COKE, CORNFLAKES)
# 184                (BISCUIT, MILK)            (CORNFLAKES, BREAD)
# 169                  (MILK, MAGGI)                          (JAM)
# 225                  (MILK, MAGGI)                   (JAM, BREAD)
# 253                 (MILK, COFFEE)              (TEA, CORNFLAKES)
# 255                  (TEA, COFFEE)             (MILK, CORNFLAKES)
# 256              (TEA, CORNFLAKES)                 (MILK, COFFEE)
# 189            (CORNFLAKES, BREAD)                (BISCUIT, MILK)
# 172                          (JAM)                  (MILK, MAGGI)
# 214             (COKE, CORNFLAKES)              (BISCUIT, COFFEE)
# 239                     (TEA, JAM)                 (MAGGI, BREAD)
# 54                          (COKE)              (BISCUIT, COFFEE)
# 224                    (MILK, JAM)                 (MAGGI, BREAD)
# 217                         (COKE)  (BISCUIT, COFFEE, CORNFLAKES)
# 51               (BISCUIT, COFFEE)                         (COKE)
# 242                 (MAGGI, BREAD)                     (TEA, JAM)
# 208  (BISCUIT, COFFEE, CORNFLAKES)                         (COKE)
# 109                          (JAM)                 (MAGGI, BREAD)
# 108                 (MAGGI, BREAD)                          (JAM)
# 229                 (MAGGI, BREAD)                    (MILK, JAM)
# 215           (COFFEE, CORNFLAKES)                (BISCUIT, COKE)
# 252                    (MILK, TEA)           (COFFEE, CORNFLAKES)
# 257           (COFFEE, CORNFLAKES)                    (MILK, TEA)
# 210                (BISCUIT, COKE)           (COFFEE, CORNFLAKES)
# 235            (TEA, MAGGI, BREAD)                          (JAM)
# 246                          (JAM)            (TEA, MAGGI, BREAD)
# 212          (BISCUIT, CORNFLAKES)                 (COKE, COFFEE)
# 63           (BISCUIT, CORNFLAKES)                         (COKE)
# 66                          (COKE)          (BISCUIT, CORNFLAKES)
# 213                 (COKE, COFFEE)          (BISCUIT, CORNFLAKES)
# 221             (MILK, JAM, BREAD)                        (MAGGI)
# 191                         (MILK)   (BISCUIT, CORNFLAKES, BREAD)
# 205                        (MAGGI)          (BISCUIT, TEA, BREAD)
# 79                         (MAGGI)                 (BISCUIT, TEA)
# 104            (CORNFLAKES, BREAD)                         (MILK)
# 74                  (BISCUIT, TEA)                        (MAGGI)
# 105                         (MILK)            (CORNFLAKES, BREAD)
# 194          (BISCUIT, TEA, BREAD)                        (MAGGI)
# 155                         (MILK)                  (TEA, COFFEE)
# 107                   (JAM, BREAD)                        (MAGGI)
# 173                        (MAGGI)                    (MILK, JAM)
# 154                  (TEA, COFFEE)                         (MILK)
# 258                         (MILK)      (TEA, COFFEE, CORNFLAKES)
# 251      (TEA, COFFEE, CORNFLAKES)                         (MILK)
# 245                        (MAGGI)              (TEA, JAM, BREAD)
# 110                        (MAGGI)                   (JAM, BREAD)
# 168                    (MILK, JAM)                        (MAGGI)
# 236              (TEA, JAM, BREAD)                        (MAGGI)
# 182   (BISCUIT, CORNFLAKES, BREAD)                         (MILK)
# 232                        (MAGGI)             (MILK, JAM, BREAD)
# 178                        (MAGGI)                     (TEA, JAM)
# 30                           (JAM)                        (MAGGI)
# 175                     (TEA, JAM)                        (MAGGI)
# 31                         (MAGGI)                          (JAM)
# 162                    (MILK, TEA)                   (CORNFLAKES)
# 151                   (CORNFLAKES)                  (TEA, COFFEE)
# 148                  (TEA, COFFEE)                   (CORNFLAKES)
# 145                   (CORNFLAKES)                 (MILK, COFFEE)
# 93                         (SUGER)            (BOURNVITA, COFFEE)
# 92             (BOURNVITA, COFFEE)                        (SUGER)
# 206        (BISCUIT, COKE, COFFEE)                   (CORNFLAKES)
# 140                 (MILK, COFFEE)                   (CORNFLAKES)
# 137                         (COKE)           (COFFEE, CORNFLAKES)
# 136           (COFFEE, CORNFLAKES)                         (COKE)
# 197                 (BISCUIT, TEA)                 (MAGGI, BREAD)
# 167                   (CORNFLAKES)                    (MILK, TEA)
# 202                 (MAGGI, BREAD)                 (BISCUIT, TEA)
# 261                   (CORNFLAKES)            (MILK, TEA, COFFEE)
# 67                    (CORNFLAKES)                (BISCUIT, COKE)
# 62                 (BISCUIT, COKE)                   (CORNFLAKES)
# 219                   (CORNFLAKES)        (BISCUIT, COKE, COFFEE)
# 248            (MILK, TEA, COFFEE)                   (CORNFLAKES)
# 61                    (CORNFLAKES)              (BISCUIT, COFFEE)
# 56               (BISCUIT, COFFEE)                   (CORNFLAKES)
# 159            (CORNFLAKES, MAGGI)                          (TEA)
# 160                          (TEA)            (CORNFLAKES, MAGGI)
# 250     (MILK, COFFEE, CORNFLAKES)                          (TEA)
# 195        (BISCUIT, MAGGI, BREAD)                          (TEA)
# 259                          (TEA)     (MILK, COFFEE, CORNFLAKES)
# 209     (COKE, COFFEE, CORNFLAKES)                      (BISCUIT)
# 183      (MILK, CORNFLAKES, BREAD)                      (BISCUIT)
# 38             (CORNFLAKES, BREAD)                      (BISCUIT)
# 39                       (BISCUIT)            (CORNFLAKES, BREAD)
# 190                      (BISCUIT)      (MILK, CORNFLAKES, BREAD)
# 153                 (MILK, COFFEE)                          (TEA)
# 78                           (TEA)               (BISCUIT, MAGGI)
# 204                          (TEA)        (BISCUIT, MAGGI, BREAD)
# 65                       (BISCUIT)             (COKE, CORNFLAKES)
# 75                (BISCUIT, MAGGI)                          (TEA)
# 156                          (TEA)                 (MILK, COFFEE)
# 216                      (BISCUIT)     (COKE, COFFEE, CORNFLAKES)
# 64              (COKE, CORNFLAKES)                      (BISCUIT)
# 122                          (JAM)                   (TEA, BREAD)
# 249        (MILK, TEA, CORNFLAKES)                       (COFFEE)
# 116                          (JAM)                  (MILK, BREAD)
# 179                          (JAM)                   (TEA, MAGGI)
# 207    (BISCUIT, COKE, CORNFLAKES)                       (COFFEE)
# 119                   (TEA, BREAD)                          (JAM)
# 174                   (TEA, MAGGI)                          (JAM)
# 55                        (COFFEE)                (BISCUIT, COKE)
# 113                  (MILK, BREAD)                          (JAM)
# 243                   (JAM, BREAD)                   (TEA, MAGGI)
# 238                   (TEA, MAGGI)                   (JAM, BREAD)
# 240                   (TEA, BREAD)                   (JAM, MAGGI)
# 138                       (COFFEE)             (COKE, CORNFLAKES)
# 241                   (JAM, MAGGI)                   (TEA, BREAD)
# 20                          (COKE)                       (COFFEE)
# 87                     (BOURNVITA)                   (TEA, BREAD)
# 146            (SUGER, CORNFLAKES)                       (COFFEE)
# 157                       (COFFEE)                    (MILK, TEA)
# 218                       (COFFEE)    (BISCUIT, COKE, CORNFLAKES)
# 50                 (BISCUIT, COKE)                       (COFFEE)
# 260                       (COFFEE)        (MILK, TEA, CORNFLAKES)
# 86                    (TEA, BREAD)                    (BOURNVITA)
# 96                   (COKE, BREAD)                       (COFFEE)
# 152                    (MILK, TEA)                       (COFFEE)
# 99                        (COFFEE)                  (COKE, BREAD)
# 187             (MILK, CORNFLAKES)               (BISCUIT, BREAD)
# 135             (COKE, CORNFLAKES)                       (COFFEE)
# 186               (BISCUIT, BREAD)             (MILK, CORNFLAKES)
# 226                  (MILK, BREAD)                   (JAM, MAGGI)
# 147                       (COFFEE)            (SUGER, CORNFLAKES)
# 227                   (JAM, MAGGI)                  (MILK, BREAD)
# 198               (BISCUIT, MAGGI)                   (TEA, BREAD)
# 201                   (TEA, BREAD)               (BISCUIT, MAGGI)
# 21                        (COFFEE)                         (COKE)
# 37                         (MAGGI)                          (TEA)
# 36                           (TEA)                        (MAGGI)
# 139                   (CORNFLAKES)                 (COKE, COFFEE)
# 134                 (COKE, COFFEE)                   (CORNFLAKES)
# 27                    (CORNFLAKES)                         (COKE)
# 97                 (COFFEE, BREAD)                         (COKE)
# 98                          (COKE)                (COFFEE, BREAD)
# 26                          (COKE)                   (CORNFLAKES)
# 101                (COFFEE, BREAD)                        (SUGER)
# 102                        (SUGER)                (COFFEE, BREAD)
# 133                        (MAGGI)                   (TEA, BREAD)
# 230                         (MILK)            (JAM, MAGGI, BREAD)
# 223            (JAM, MAGGI, BREAD)                         (MILK)
# 46                          (MILK)               (BISCUIT, BREAD)
# 158              (TEA, CORNFLAKES)                        (MAGGI)
# 43                (BISCUIT, BREAD)                         (MILK)
# 115                         (MILK)                   (JAM, BREAD)
# 164              (TEA, CORNFLAKES)                         (MILK)
# 33                           (JAM)                         (MILK)
# 32                          (MILK)                          (JAM)
# 161                        (MAGGI)              (TEA, CORNFLAKES)
# 171                         (MILK)                   (JAM, MAGGI)
# 170                   (JAM, MAGGI)                         (MILK)
# 130                   (TEA, BREAD)                        (MAGGI)
# 165                         (MILK)              (TEA, CORNFLAKES)
# 114                   (JAM, BREAD)                         (MILK)
# 0                        (BISCUIT)                         (COKE)
# 131                 (MAGGI, BREAD)                          (TEA)
# 132                          (TEA)                 (MAGGI, BREAD)
# 88                           (TEA)             (BOURNVITA, BREAD)
# 85              (BOURNVITA, BREAD)                          (TEA)
# 53                       (BISCUIT)                 (COKE, COFFEE)
# 1                           (COKE)                      (BISCUIT)
# 52                  (COKE, COFFEE)                      (BISCUIT)
# 24                         (SUGER)                       (COFFEE)
# 23                    (CORNFLAKES)                       (COFFEE)
# 25                        (COFFEE)                        (SUGER)
# 181         (BISCUIT, MILK, BREAD)                   (CORNFLAKES)
# 22                        (COFFEE)                   (CORNFLAKES)
# 57           (BISCUIT, CORNFLAKES)                       (COFFEE)
# 60                        (COFFEE)          (BISCUIT, CORNFLAKES)
# 68                 (BISCUIT, MILK)                   (CORNFLAKES)
# 11                     (BOURNVITA)                        (SUGER)
# 10                         (SUGER)                    (BOURNVITA)
# 192                   (CORNFLAKES)         (BISCUIT, MILK, BREAD)
# 188                  (MILK, BREAD)          (BISCUIT, CORNFLAKES)
# 185          (BISCUIT, CORNFLAKES)                  (MILK, BREAD)
# 73                    (CORNFLAKES)                (BISCUIT, MILK)
# 47                         (BREAD)                (BISCUIT, MILK)
# 233                        (BREAD)             (MILK, JAM, MAGGI)
# 193                        (BREAD)    (BISCUIT, MILK, CORNFLAKES)
# 117                        (BREAD)                    (MILK, JAM)
# 129                        (BREAD)                  (MILK, MAGGI)
# 49                         (BREAD)               (SUGER, BISCUIT)
# 123                        (BREAD)                     (TEA, JAM)
# 89                         (BREAD)               (BOURNVITA, TEA)
# 111                        (BREAD)                   (JAM, MAGGI)
# 15                         (BREAD)                          (JAM)
# 247                        (BREAD)              (JAM, TEA, MAGGI)
# 42                 (BISCUIT, MILK)                        (BREAD)
# 234              (JAM, TEA, MAGGI)                        (BREAD)
# 48                (SUGER, BISCUIT)                        (BREAD)
# 84                (BOURNVITA, TEA)                        (BREAD)
# 14                           (JAM)                        (BREAD)
# 124                  (MILK, MAGGI)                        (BREAD)
# 118                     (TEA, JAM)                        (BREAD)
# 220             (MILK, JAM, MAGGI)                        (BREAD)
# 112                    (MILK, JAM)                        (BREAD)
# 106                   (JAM, MAGGI)                        (BREAD)
# 180    (BISCUIT, MILK, CORNFLAKES)                        (BREAD)
# 2                        (BISCUIT)                   (CORNFLAKES)
# 59                       (BISCUIT)           (COFFEE, CORNFLAKES)
# 35                           (JAM)                          (TEA)
# 176                   (JAM, MAGGI)                          (TEA)
# 44                   (MILK, BREAD)                      (BISCUIT)
# 45                       (BISCUIT)                  (MILK, BREAD)
# 166                          (TEA)             (MILK, CORNFLAKES)
# 120                   (JAM, BREAD)                          (TEA)
# 237            (JAM, MAGGI, BREAD)                          (TEA)
# 163             (MILK, CORNFLAKES)                          (TEA)
# 244                          (TEA)            (JAM, MAGGI, BREAD)
# 58            (COFFEE, CORNFLAKES)                      (BISCUIT)
# 196            (TEA, MAGGI, BREAD)                      (BISCUIT)
# 76                    (TEA, MAGGI)                      (BISCUIT)
# 177                          (TEA)                   (JAM, MAGGI)
# 3                     (CORNFLAKES)                      (BISCUIT)
# 121                          (TEA)                   (JAM, BREAD)
# 203                      (BISCUIT)            (TEA, MAGGI, BREAD)
# 12                     (BOURNVITA)                          (TEA)
# 13                           (TEA)                    (BOURNVITA)
# 77                       (BISCUIT)                   (TEA, MAGGI)
# 34                           (TEA)                          (JAM)
# 71                       (BISCUIT)             (MILK, CORNFLAKES)
# 70              (MILK, CORNFLAKES)                      (BISCUIT)
# 29                    (CORNFLAKES)                         (MILK)
# 72                          (MILK)          (BISCUIT, CORNFLAKES)
# 127                         (MILK)                 (MAGGI, BREAD)
# 28                          (MILK)                   (CORNFLAKES)
# 126                 (MAGGI, BREAD)                         (MILK)
# 69           (BISCUIT, CORNFLAKES)                         (MILK)
# 141             (MILK, CORNFLAKES)                       (COFFEE)
# 144                       (COFFEE)             (MILK, CORNFLAKES)
# 150                       (COFFEE)              (TEA, CORNFLAKES)
# 90              (SUGER, BOURNVITA)                       (COFFEE)
# 91                 (SUGER, COFFEE)                    (BOURNVITA)
# 199               (BISCUIT, BREAD)                   (TEA, MAGGI)
# 200                   (TEA, MAGGI)               (BISCUIT, BREAD)
# 83                     (BOURNVITA)                 (SUGER, BREAD)
# 80                  (SUGER, BREAD)                    (BOURNVITA)
# 149              (TEA, CORNFLAKES)                       (COFFEE)
# 94                     (BOURNVITA)                (SUGER, COFFEE)
# 95                        (COFFEE)             (SUGER, BOURNVITA)
# 103                       (COFFEE)                 (SUGER, BREAD)
# 100                 (SUGER, BREAD)                       (COFFEE)
# 17                         (BREAD)                         (MILK)
# 16                          (MILK)                        (BREAD)
# 8                      (BOURNVITA)                        (BREAD)
# 9                          (BREAD)                    (BOURNVITA)
# 7                           (MILK)                      (BISCUIT)
# 6                        (BISCUIT)                         (MILK)
# 5                          (MAGGI)                      (BISCUIT)
# 4                        (BISCUIT)                        (MAGGI)
# 82                         (SUGER)             (BOURNVITA, BREAD)
# 81              (BOURNVITA, BREAD)                        (SUGER)
# 19                         (BREAD)                        (SUGER)
# 18                         (SUGER)                        (BREAD)
# 142           (COFFEE, CORNFLAKES)                         (MILK)
# 143                         (MILK)           (COFFEE, CORNFLAKES)
# 41                         (MAGGI)               (BISCUIT, BREAD)
# 125                  (MILK, BREAD)                        (MAGGI)
# 128                        (MAGGI)                  (MILK, BREAD)
# 40                (BISCUIT, BREAD)                        (MAGGI)
#
#      antecedent support  consequent support  support  confidence       lift  \
# 228                0.10                0.05     0.05    0.500000  10.000000
# 254                0.10                0.05     0.05    0.500000  10.000000
# 231                0.10                0.05     0.05    0.500000  10.000000
# 222                0.05                0.10     0.05    1.000000  10.000000
# 211                0.10                0.10     0.10    1.000000  10.000000
# 184                0.10                0.05     0.05    0.500000  10.000000
# 169                0.05                0.10     0.05    1.000000  10.000000
# 225                0.05                0.10     0.05    1.000000  10.000000
# 253                0.05                0.10     0.05    1.000000  10.000000
# 255                0.05                0.10     0.05    1.000000  10.000000
# 256                0.10                0.05     0.05    0.500000  10.000000
# 189                0.05                0.10     0.05    1.000000  10.000000
# 172                0.10                0.05     0.05    0.500000  10.000000
# 214                0.10                0.10     0.10    1.000000  10.000000
# 239                0.05                0.15     0.05    1.000000   6.666667
# 54                 0.15                0.10     0.10    0.666667   6.666667
# 224                0.05                0.15     0.05    1.000000   6.666667
# 217                0.15                0.10     0.10    0.666667   6.666667
# 51                 0.10                0.15     0.10    1.000000   6.666667
# 242                0.15                0.05     0.05    0.333333   6.666667
# 208                0.10                0.15     0.10    1.000000   6.666667
# 109                0.10                0.15     0.10    1.000000   6.666667
# 108                0.15                0.10     0.10    0.666667   6.666667
# 229                0.15                0.05     0.05    0.333333   6.666667
# 215                0.20                0.10     0.10    0.500000   5.000000
# 252                0.05                0.20     0.05    1.000000   5.000000
# 257                0.20                0.05     0.05    0.250000   5.000000
# 210                0.10                0.20     0.10    1.000000   5.000000
# 235                0.10                0.10     0.05    0.500000   5.000000
# 246                0.10                0.10     0.05    0.500000   5.000000
# 212                0.15                0.15     0.10    0.666667   4.444444
# 63                 0.15                0.15     0.10    0.666667   4.444444
# 66                 0.15                0.15     0.10    0.666667   4.444444
# 213                0.15                0.15     0.10    0.666667   4.444444
# 221                0.05                0.25     0.05    1.000000   4.000000
# 191                0.25                0.05     0.05    0.200000   4.000000
# 205                0.25                0.05     0.05    0.200000   4.000000
# 79                 0.25                0.10     0.10    0.400000   4.000000
# 104                0.05                0.25     0.05    1.000000   4.000000
# 74                 0.10                0.25     0.10    1.000000   4.000000
# 105                0.25                0.05     0.05    0.200000   4.000000
# 194                0.05                0.25     0.05    1.000000   4.000000
# 155                0.25                0.05     0.05    0.200000   4.000000
# 107                0.10                0.25     0.10    1.000000   4.000000
# 173                0.25                0.05     0.05    0.200000   4.000000
# 154                0.05                0.25     0.05    1.000000   4.000000
# 258                0.25                0.05     0.05    0.200000   4.000000
# 251                0.05                0.25     0.05    1.000000   4.000000
# 245                0.25                0.05     0.05    0.200000   4.000000
# 110                0.25                0.10     0.10    0.400000   4.000000
# 168                0.05                0.25     0.05    1.000000   4.000000
# 236                0.05                0.25     0.05    1.000000   4.000000
# 182                0.05                0.25     0.05    1.000000   4.000000
# 232                0.25                0.05     0.05    0.200000   4.000000
# 178                0.25                0.05     0.05    0.200000   4.000000
# 30                 0.10                0.25     0.10    1.000000   4.000000
# 175                0.05                0.25     0.05    1.000000   4.000000
# 31                 0.25                0.10     0.10    0.400000   4.000000
# 162                0.05                0.30     0.05    1.000000   3.333333
# 151                0.30                0.05     0.05    0.166667   3.333333
# 148                0.05                0.30     0.05    1.000000   3.333333
# 145                0.30                0.05     0.05    0.166667   3.333333
# 93                 0.30                0.05     0.05    0.166667   3.333333
# 92                 0.05                0.30     0.05    1.000000   3.333333
# 206                0.10                0.30     0.10    1.000000   3.333333
# 140                0.05                0.30     0.05    1.000000   3.333333
# 137                0.15                0.20     0.10    0.666667   3.333333
# 136                0.20                0.15     0.10    0.500000   3.333333
# 197                0.10                0.15     0.05    0.500000   3.333333
# 167                0.30                0.05     0.05    0.166667   3.333333
# 202                0.15                0.10     0.05    0.333333   3.333333
# 261                0.30                0.05     0.05    0.166667   3.333333
# 67                 0.30                0.10     0.10    0.333333   3.333333
# 62                 0.10                0.30     0.10    1.000000   3.333333
# 219                0.30                0.10     0.10    0.333333   3.333333
# 248                0.05                0.30     0.05    1.000000   3.333333
# 61                 0.30                0.10     0.10    0.333333   3.333333
# 56                 0.10                0.30     0.10    1.000000   3.333333
# 159                0.05                0.35     0.05    1.000000   2.857143
# 160                0.35                0.05     0.05    0.142857   2.857143
# 250                0.05                0.35     0.05    1.000000   2.857143
# 195                0.05                0.35     0.05    1.000000   2.857143
# 259                0.35                0.05     0.05    0.142857   2.857143
# 209                0.10                0.35     0.10    1.000000   2.857143
# 183                0.05                0.35     0.05    1.000000   2.857143
# 38                 0.05                0.35     0.05    1.000000   2.857143
# 39                 0.35                0.05     0.05    0.142857   2.857143
# 190                0.35                0.05     0.05    0.142857   2.857143
# 153                0.05                0.35     0.05    1.000000   2.857143
# 78                 0.35                0.10     0.10    0.285714   2.857143
# 204                0.35                0.05     0.05    0.142857   2.857143
# 65                 0.35                0.10     0.10    0.285714   2.857143
# 75                 0.10                0.35     0.10    1.000000   2.857143
# 156                0.35                0.05     0.05    0.142857   2.857143
# 216                0.35                0.10     0.10    0.285714   2.857143
# 64                 0.10                0.35     0.10    1.000000   2.857143
# 122                0.10                0.20     0.05    0.500000   2.500000
# 249                0.05                0.40     0.05    1.000000   2.500000
# 116                0.10                0.20     0.05    0.500000   2.500000
# 179                0.10                0.20     0.05    0.500000   2.500000
# 207                0.10                0.40     0.10    1.000000   2.500000
# 119                0.20                0.10     0.05    0.250000   2.500000
# 174                0.20                0.10     0.05    0.250000   2.500000
# 55                 0.40                0.10     0.10    0.250000   2.500000
# 113                0.20                0.10     0.05    0.250000   2.500000
# 243                0.10                0.20     0.05    0.500000   2.500000
# 238                0.20                0.10     0.05    0.250000   2.500000
# 240                0.20                0.10     0.05    0.250000   2.500000
# 138                0.40                0.10     0.10    0.250000   2.500000
# 241                0.10                0.20     0.05    0.500000   2.500000
# 20                 0.15                0.40     0.15    1.000000   2.500000
# 87                 0.20                0.20     0.10    0.500000   2.500000
# 146                0.05                0.40     0.05    1.000000   2.500000
# 157                0.40                0.05     0.05    0.125000   2.500000
# 218                0.40                0.10     0.10    0.250000   2.500000
# 50                 0.10                0.40     0.10    1.000000   2.500000
# 260                0.40                0.05     0.05    0.125000   2.500000
# 86                 0.20                0.20     0.10    0.500000   2.500000
# 96                 0.05                0.40     0.05    1.000000   2.500000
# 152                0.05                0.40     0.05    1.000000   2.500000
# 99                 0.40                0.05     0.05    0.125000   2.500000
# 187                0.10                0.20     0.05    0.500000   2.500000
# 135                0.10                0.40     0.10    1.000000   2.500000
# 186                0.20                0.10     0.05    0.250000   2.500000
# 226                0.20                0.10     0.05    0.250000   2.500000
# 147                0.40                0.05     0.05    0.125000   2.500000
# 227                0.10                0.20     0.05    0.500000   2.500000
# 198                0.10                0.20     0.05    0.500000   2.500000
# 201                0.20                0.10     0.05    0.250000   2.500000
# 21                 0.40                0.15     0.15    0.375000   2.500000
# 37                 0.25                0.35     0.20    0.800000   2.285714
# 36                 0.35                0.25     0.20    0.571429   2.285714
# 139                0.30                0.15     0.10    0.333333   2.222222
# 134                0.15                0.30     0.10    0.666667   2.222222
# 27                 0.30                0.15     0.10    0.333333   2.222222
# 97                 0.15                0.15     0.05    0.333333   2.222222
# 98                 0.15                0.15     0.05    0.333333   2.222222
# 26                 0.15                0.30     0.10    0.666667   2.222222
# 101                0.15                0.30     0.10    0.666667   2.222222
# 102                0.30                0.15     0.10    0.333333   2.222222
# 133                0.25                0.20     0.10    0.400000   2.000000
# 230                0.25                0.10     0.05    0.200000   2.000000
# 223                0.10                0.25     0.05    0.500000   2.000000
# 46                 0.25                0.20     0.10    0.400000   2.000000
# 158                0.10                0.25     0.05    0.500000   2.000000
# 43                 0.20                0.25     0.10    0.500000   2.000000
# 115                0.25                0.10     0.05    0.200000   2.000000
# 164                0.10                0.25     0.05    0.500000   2.000000
# 33                 0.10                0.25     0.05    0.500000   2.000000
# 32                 0.25                0.10     0.05    0.200000   2.000000
# 161                0.25                0.10     0.05    0.200000   2.000000
# 171                0.25                0.10     0.05    0.200000   2.000000
# 170                0.10                0.25     0.05    0.500000   2.000000
# 130                0.20                0.25     0.10    0.500000   2.000000
# 165                0.25                0.10     0.05    0.200000   2.000000
# 114                0.10                0.25     0.05    0.500000   2.000000
# 0                  0.35                0.15     0.10    0.285714   1.904762
# 131                0.15                0.35     0.10    0.666667   1.904762
# 132                0.35                0.15     0.10    0.285714   1.904762
# 88                 0.35                0.15     0.10    0.285714   1.904762
# 85                 0.15                0.35     0.10    0.666667   1.904762
# 53                 0.35                0.15     0.10    0.285714   1.904762
# 1                  0.15                0.35     0.10    0.666667   1.904762
# 52                 0.15                0.35     0.10    0.666667   1.904762
# 24                 0.30                0.40     0.20    0.666667   1.666667
# 23                 0.30                0.40     0.20    0.666667   1.666667
# 25                 0.40                0.30     0.20    0.500000   1.666667
# 181                0.10                0.30     0.05    0.500000   1.666667
# 22                 0.40                0.30     0.20    0.500000   1.666667
# 57                 0.15                0.40     0.10    0.666667   1.666667
# 60                 0.40                0.15     0.10    0.250000   1.666667
# 68                 0.10                0.30     0.05    0.500000   1.666667
# 11                 0.20                0.30     0.10    0.500000   1.666667
# 10                 0.30                0.20     0.10    0.333333   1.666667
# 192                0.30                0.10     0.05    0.166667   1.666667
# 188                0.20                0.15     0.05    0.250000   1.666667
# 185                0.15                0.20     0.05    0.333333   1.666667
# 73                 0.30                0.10     0.05    0.166667   1.666667
# 47                 0.65                0.10     0.10    0.153846   1.538462
# 233                0.65                0.05     0.05    0.076923   1.538462
# 193                0.65                0.05     0.05    0.076923   1.538462
# 117                0.65                0.05     0.05    0.076923   1.538462
# 129                0.65                0.05     0.05    0.076923   1.538462
# 49                 0.65                0.05     0.05    0.076923   1.538462
# 123                0.65                0.05     0.05    0.076923   1.538462
# 89                 0.65                0.10     0.10    0.153846   1.538462
# 111                0.65                0.10     0.10    0.153846   1.538462
# 15                 0.65                0.10     0.10    0.153846   1.538462
# 247                0.65                0.05     0.05    0.076923   1.538462
# 42                 0.10                0.65     0.10    1.000000   1.538462
# 234                0.05                0.65     0.05    1.000000   1.538462
# 48                 0.05                0.65     0.05    1.000000   1.538462
# 84                 0.10                0.65     0.10    1.000000   1.538462
# 14                 0.10                0.65     0.10    1.000000   1.538462
# 124                0.05                0.65     0.05    1.000000   1.538462
# 118                0.05                0.65     0.05    1.000000   1.538462
# 220                0.05                0.65     0.05    1.000000   1.538462
# 112                0.05                0.65     0.05    1.000000   1.538462
# 106                0.10                0.65     0.10    1.000000   1.538462
# 180                0.05                0.65     0.05    1.000000   1.538462
# 2                  0.35                0.30     0.15    0.428571   1.428571
# 59                 0.35                0.20     0.10    0.285714   1.428571
# 35                 0.10                0.35     0.05    0.500000   1.428571
# 176                0.10                0.35     0.05    0.500000   1.428571
# 44                 0.20                0.35     0.10    0.500000   1.428571
# 45                 0.35                0.20     0.10    0.285714   1.428571
# 166                0.35                0.10     0.05    0.142857   1.428571
# 120                0.10                0.35     0.05    0.500000   1.428571
# 237                0.10                0.35     0.05    0.500000   1.428571
# 163                0.10                0.35     0.05    0.500000   1.428571
# 244                0.35                0.10     0.05    0.142857   1.428571
# 58                 0.20                0.35     0.10    0.500000   1.428571
# 196                0.10                0.35     0.05    0.500000   1.428571
# 76                 0.20                0.35     0.10    0.500000   1.428571
# 177                0.35                0.10     0.05    0.142857   1.428571
# 3                  0.30                0.35     0.15    0.500000   1.428571
# 121                0.35                0.10     0.05    0.142857   1.428571
# 203                0.35                0.10     0.05    0.142857   1.428571
# 12                 0.20                0.35     0.10    0.500000   1.428571
# 13                 0.35                0.20     0.10    0.285714   1.428571
# 77                 0.35                0.20     0.10    0.285714   1.428571
# 34                 0.35                0.10     0.05    0.142857   1.428571
# 71                 0.35                0.10     0.05    0.142857   1.428571
# 70                 0.10                0.35     0.05    0.500000   1.428571
# 29                 0.30                0.25     0.10    0.333333   1.333333
# 72                 0.25                0.15     0.05    0.200000   1.333333
# 127                0.25                0.15     0.05    0.200000   1.333333
# 28                 0.25                0.30     0.10    0.400000   1.333333
# 126                0.15                0.25     0.05    0.333333   1.333333
# 69                 0.15                0.25     0.05    0.333333   1.333333
# 141                0.10                0.40     0.05    0.500000   1.250000
# 144                0.40                0.10     0.05    0.125000   1.250000
# 150                0.40                0.10     0.05    0.125000   1.250000
# 90                 0.10                0.40     0.05    0.500000   1.250000
# 91                 0.20                0.20     0.05    0.250000   1.250000
# 199                0.20                0.20     0.05    0.250000   1.250000
# 200                0.20                0.20     0.05    0.250000   1.250000
# 83                 0.20                0.20     0.05    0.250000   1.250000
# 80                 0.20                0.20     0.05    0.250000   1.250000
# 149                0.10                0.40     0.05    0.500000   1.250000
# 94                 0.20                0.20     0.05    0.250000   1.250000
# 95                 0.40                0.10     0.05    0.125000   1.250000
# 103                0.40                0.20     0.10    0.250000   1.250000
# 100                0.20                0.40     0.10    0.500000   1.250000
# 17                 0.65                0.25     0.20    0.307692   1.230769
# 16                 0.25                0.65     0.20    0.800000   1.230769
# 8                  0.20                0.65     0.15    0.750000   1.153846
# 9                  0.65                0.20     0.15    0.230769   1.153846
# 7                  0.25                0.35     0.10    0.400000   1.142857
# 6                  0.35                0.25     0.10    0.285714   1.142857
# 5                  0.25                0.35     0.10    0.400000   1.142857
# 4                  0.35                0.25     0.10    0.285714   1.142857
# 82                 0.30                0.15     0.05    0.166667   1.111111
# 81                 0.15                0.30     0.05    0.333333   1.111111
# 19                 0.65                0.30     0.20    0.307692   1.025641
# 18                 0.30                0.65     0.20    0.666667   1.025641
# 142                0.20                0.25     0.05    0.250000   1.000000
# 143                0.25                0.20     0.05    0.200000   1.000000
# 41                 0.25                0.20     0.05    0.200000   1.000000
# 125                0.20                0.25     0.05    0.250000   1.000000
# 128                0.25                0.20     0.05    0.200000   1.000000
# 40                 0.20                0.25     0.05    0.250000   1.000000
#
#      leverage  conviction  zhangs_metric
# 228    0.0450    1.900000       1.000000
# 254    0.0450    1.900000       1.000000
# 231    0.0450    1.900000       1.000000
# 222    0.0450         inf       0.947368
# 211    0.0900         inf       1.000000
# 184    0.0450    1.900000       1.000000
# 169    0.0450         inf       0.947368
# 225    0.0450         inf       0.947368
# 253    0.0450         inf       0.947368
# 255    0.0450         inf       0.947368
# 256    0.0450    1.900000       1.000000
# 189    0.0450         inf       0.947368
# 172    0.0450    1.900000       1.000000
# 214    0.0900         inf       1.000000
# 239    0.0425         inf       0.894737
# 54     0.0850    2.700000       1.000000
# 224    0.0425         inf       0.894737
# 217    0.0850    2.700000       1.000000
# 51     0.0850         inf       0.944444
# 242    0.0425    1.425000       1.000000
# 208    0.0850         inf       0.944444
# 109    0.0850         inf       0.944444
# 108    0.0850    2.700000       1.000000
# 229    0.0425    1.425000       1.000000
# 215    0.0800    1.800000       1.000000
# 252    0.0400         inf       0.842105
# 257    0.0400    1.266667       1.000000
# 210    0.0800         inf       0.888889
# 235    0.0400    1.800000       0.888889
# 246    0.0400    1.800000       0.888889
# 212    0.0775    2.550000       0.911765
# 63     0.0775    2.550000       0.911765
# 66     0.0775    2.550000       0.911765
# 213    0.0775    2.550000       0.911765
# 221    0.0375         inf       0.789474
# 191    0.0375    1.187500       1.000000
# 205    0.0375    1.187500       1.000000
# 79     0.0750    1.500000       1.000000
# 104    0.0375         inf       0.789474
# 74     0.0750         inf       0.833333
# 105    0.0375    1.187500       1.000000
# 194    0.0375         inf       0.789474
# 155    0.0375    1.187500       1.000000
# 107    0.0750         inf       0.833333
# 173    0.0375    1.187500       1.000000
# 154    0.0375         inf       0.789474
# 258    0.0375    1.187500       1.000000
# 251    0.0375         inf       0.789474
# 245    0.0375    1.187500       1.000000
# 110    0.0750    1.500000       1.000000
# 168    0.0375         inf       0.789474
# 236    0.0375         inf       0.789474
# 182    0.0375         inf       0.789474
# 232    0.0375    1.187500       1.000000
# 178    0.0375    1.187500       1.000000
# 30     0.0750         inf       0.833333
# 175    0.0375         inf       0.789474
# 31     0.0750    1.500000       1.000000
# 162    0.0350         inf       0.736842
# 151    0.0350    1.140000       1.000000
# 148    0.0350         inf       0.736842
# 145    0.0350    1.140000       1.000000
# 93     0.0350    1.140000       1.000000
# 92     0.0350         inf       0.736842
# 206    0.0700         inf       0.777778
# 140    0.0350         inf       0.736842
# 137    0.0700    2.400000       0.823529
# 136    0.0700    1.700000       0.875000
# 197    0.0350    1.700000       0.777778
# 167    0.0350    1.140000       1.000000
# 202    0.0350    1.350000       0.823529
# 261    0.0350    1.140000       1.000000
# 67     0.0700    1.350000       1.000000
# 62     0.0700         inf       0.777778
# 219    0.0700    1.350000       1.000000
# 248    0.0350         inf       0.736842
# 61     0.0700    1.350000       1.000000
# 56     0.0700         inf       0.777778
# 159    0.0325         inf       0.684211
# 160    0.0325    1.108333       1.000000
# 250    0.0325         inf       0.684211
# 195    0.0325         inf       0.684211
# 259    0.0325    1.108333       1.000000
# 209    0.0650         inf       0.722222
# 183    0.0325         inf       0.684211
# 38     0.0325         inf       0.684211
# 39     0.0325    1.108333       1.000000
# 190    0.0325    1.108333       1.000000
# 153    0.0325         inf       0.684211
# 78     0.0650    1.260000       1.000000
# 204    0.0325    1.108333       1.000000
# 65     0.0650    1.260000       1.000000
# 75     0.0650         inf       0.722222
# 156    0.0325    1.108333       1.000000
# 216    0.0650    1.260000       1.000000
# 64     0.0650         inf       0.722222
# 122    0.0300    1.600000       0.666667
# 249    0.0300         inf       0.631579
# 116    0.0300    1.600000       0.666667
# 179    0.0300    1.600000       0.666667
# 207    0.0600         inf       0.666667
# 119    0.0300    1.200000       0.750000
# 174    0.0300    1.200000       0.750000
# 55     0.0600    1.200000       1.000000
# 113    0.0300    1.200000       0.750000
# 243    0.0300    1.600000       0.666667
# 238    0.0300    1.200000       0.750000
# 240    0.0300    1.200000       0.750000
# 138    0.0600    1.200000       1.000000
# 241    0.0300    1.600000       0.666667
# 20     0.0900         inf       0.705882
# 87     0.0600    1.600000       0.750000
# 146    0.0300         inf       0.631579
# 157    0.0300    1.085714       1.000000
# 218    0.0600    1.200000       1.000000
# 50     0.0600         inf       0.666667
# 260    0.0300    1.085714       1.000000
# 86     0.0600    1.600000       0.750000
# 96     0.0300         inf       0.631579
# 152    0.0300         inf       0.631579
# 99     0.0300    1.085714       1.000000
# 187    0.0300    1.600000       0.666667
# 135    0.0600         inf       0.666667
# 186    0.0300    1.200000       0.750000
# 226    0.0300    1.200000       0.750000
# 147    0.0300    1.085714       1.000000
# 227    0.0300    1.600000       0.666667
# 198    0.0300    1.600000       0.666667
# 201    0.0300    1.200000       0.750000
# 21     0.0900    1.360000       1.000000
# 37     0.1125    3.250000       0.750000
# 36     0.1125    1.750000       0.865385
# 139    0.0550    1.275000       0.785714
# 134    0.0550    2.100000       0.647059
# 27     0.0550    1.275000       0.785714
# 97     0.0275    1.275000       0.647059
# 98     0.0275    1.275000       0.647059
# 26     0.0550    2.100000       0.647059
# 101    0.0550    2.100000       0.647059
# 102    0.0550    1.275000       0.785714
# 133    0.0500    1.333333       0.666667
# 230    0.0250    1.125000       0.666667
# 223    0.0250    1.500000       0.555556
# 46     0.0500    1.333333       0.666667
# 158    0.0250    1.500000       0.555556
# 43     0.0500    1.500000       0.625000
# 115    0.0250    1.125000       0.666667
# 164    0.0250    1.500000       0.555556
# 33     0.0250    1.500000       0.555556
# 32     0.0250    1.125000       0.666667
# 161    0.0250    1.125000       0.666667
# 171    0.0250    1.125000       0.666667
# 170    0.0250    1.500000       0.555556
# 130    0.0500    1.500000       0.625000
# 165    0.0250    1.125000       0.666667
# 114    0.0250    1.500000       0.555556
# 0      0.0475    1.190000       0.730769
# 131    0.0475    1.950000       0.558824
# 132    0.0475    1.190000       0.730769
# 88     0.0475    1.190000       0.730769
# 85     0.0475    1.950000       0.558824
# 53     0.0475    1.190000       0.730769
# 1      0.0475    1.950000       0.558824
# 52     0.0475    1.950000       0.558824
# 24     0.0800    1.800000       0.571429
# 23     0.0800    1.800000       0.571429
# 25     0.0800    1.400000       0.666667
# 181    0.0200    1.400000       0.444444
# 22     0.0800    1.400000       0.666667
# 57     0.0400    1.800000       0.470588
# 60     0.0400    1.133333       0.666667
# 68     0.0200    1.400000       0.444444
# 11     0.0400    1.400000       0.500000
# 10     0.0400    1.200000       0.571429
# 192    0.0200    1.080000       0.571429
# 188    0.0200    1.133333       0.500000
# 185    0.0200    1.200000       0.470588
# 73     0.0200    1.080000       0.571429
# 47     0.0350    1.063636       1.000000
# 233    0.0175    1.029167       1.000000
# 193    0.0175    1.029167       1.000000
# 117    0.0175    1.029167       1.000000
# 129    0.0175    1.029167       1.000000
# 49     0.0175    1.029167       1.000000
# 123    0.0175    1.029167       1.000000
# 89     0.0350    1.063636       1.000000
# 111    0.0350    1.063636       1.000000
# 15     0.0350    1.063636       1.000000
# 247    0.0175    1.029167       1.000000
# 42     0.0350         inf       0.388889
# 234    0.0175         inf       0.368421
# 48     0.0175         inf       0.368421
# 84     0.0350         inf       0.388889
# 14     0.0350         inf       0.388889
# 124    0.0175         inf       0.368421
# 118    0.0175         inf       0.368421
# 220    0.0175         inf       0.368421
# 112    0.0175         inf       0.368421
# 106    0.0350         inf       0.388889
# 180    0.0175         inf       0.368421
# 2      0.0450    1.225000       0.461538
# 59     0.0300    1.120000       0.461538
# 35     0.0150    1.300000       0.333333
# 176    0.0150    1.300000       0.333333
# 44     0.0300    1.300000       0.375000
# 45     0.0300    1.120000       0.461538
# 166    0.0150    1.050000       0.461538
# 120    0.0150    1.300000       0.333333
# 237    0.0150    1.300000       0.333333
# 163    0.0150    1.300000       0.333333
# 244    0.0150    1.050000       0.461538
# 58     0.0300    1.300000       0.375000
# 196    0.0150    1.300000       0.333333
# 76     0.0300    1.300000       0.375000
# 177    0.0150    1.050000       0.461538
# 3      0.0450    1.300000       0.428571
# 121    0.0150    1.050000       0.461538
# 203    0.0150    1.050000       0.461538
# 12     0.0300    1.300000       0.375000
# 13     0.0300    1.120000       0.461538
# 77     0.0300    1.120000       0.461538
# 34     0.0150    1.050000       0.461538
# 71     0.0150    1.050000       0.461538
# 70     0.0150    1.300000       0.333333
# 29     0.0250    1.125000       0.357143
# 72     0.0125    1.062500       0.333333
# 127    0.0125    1.062500       0.333333
# 28     0.0250    1.166667       0.333333
# 126    0.0125    1.125000       0.294118
# 69     0.0125    1.125000       0.294118
# 141    0.0100    1.200000       0.222222
# 144    0.0100    1.028571       0.333333
# 150    0.0100    1.028571       0.333333
# 90     0.0100    1.200000       0.222222
# 91     0.0100    1.066667       0.250000
# 199    0.0100    1.066667       0.250000
# 200    0.0100    1.066667       0.250000
# 83     0.0100    1.066667       0.250000
# 80     0.0100    1.066667       0.250000
# 149    0.0100    1.200000       0.222222
# 94     0.0100    1.066667       0.250000
# 95     0.0100    1.028571       0.333333
# 103    0.0200    1.066667       0.333333
# 100    0.0200    1.200000       0.250000
# 17     0.0375    1.083333       0.535714
# 16     0.0375    1.750000       0.250000
# 8      0.0200    1.400000       0.166667
# 9      0.0200    1.040000       0.380952
# 7      0.0125    1.083333       0.166667
# 6      0.0125    1.050000       0.192308
# 5      0.0125    1.083333       0.166667
# 4      0.0125    1.050000       0.192308
# 82     0.0050    1.020000       0.142857
# 81     0.0050    1.050000       0.117647
# 19     0.0050    1.011111       0.071429
# 18     0.0050    1.050000       0.035714
# 142    0.0000    1.000000       0.000000
# 143    0.0000    1.000000       0.000000
# 41     0.0000    1.000000       0.000000
# 125    0.0000    1.000000       0.000000
# 128    0.0000    1.000000       0.000000
# 40     0.0000    1.000000       0.000000

# %%
df_lift = association_rules(df1, metric = 'lift', min_threshold = 0) # displaying results with lift >= 0
df_lift[df_lift['lift'] == 1]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#               antecedents           consequents  antecedent support  \
# 79       (BISCUIT, BREAD)               (MAGGI)                0.20
# 82                (MAGGI)      (BISCUIT, BREAD)                0.25
# 187         (MILK, BREAD)               (MAGGI)                0.20
# 190               (MAGGI)         (MILK, BREAD)                0.25
# 206  (COFFEE, CORNFLAKES)                (MILK)                0.20
# 207                (MILK)  (COFFEE, CORNFLAKES)                0.25
#
#      consequent support  support  confidence  lift  leverage  conviction  \
# 79                 0.25     0.05        0.25   1.0       0.0         1.0
# 82                 0.20     0.05        0.20   1.0       0.0         1.0
# 187                0.25     0.05        0.25   1.0       0.0         1.0
# 190                0.20     0.05        0.20   1.0       0.0         1.0
# 206                0.25     0.05        0.25   1.0       0.0         1.0
# 207                0.20     0.05        0.20   1.0       0.0         1.0
#
#      zhangs_metric
# 79             0.0
# 82             0.0
# 187            0.0
# 190            0.0
# 206            0.0
# 207            0.0
